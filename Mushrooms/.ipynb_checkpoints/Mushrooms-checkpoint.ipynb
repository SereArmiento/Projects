# %%
# ! pip install ucimlrepo
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy.stats import chi2_contingency
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, precision_score 
import category_encoders as ce
from sklearn.inspection import PartialDependenceDisplay

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
mushroom = fetch_ucirepo(id=73) 
  
# data (as pandas dataframes) 
X_original = mushroom.data.features 
y_original = mushroom.data.targets 
  
# metadata 
print(mushroom.metadata) 
  
# variable information 
print(mushroom.variables)
# Out:
# {'uci_id': 73, 'name': 'Mushroom', 'repository_url': 'https://archive.ics.uci.edu/dataset/73/mushroom', 'data_url': 'https://archive.ics.uci.edu/static/public/73/data.csv', 'abstract': 'From Audobon Society Field Guide; mushrooms described in terms of physical characteristics; classification: poisonous or edible', 'area': 'Biology', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 8124, 'num_features': 22, 'feature_types': ['Categorical'], 'demographics': [], 'target_col': ['poisonous'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1981, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C5959T', 'creators': [], 'intro_paper': None, 'additional_info': {'summary': "This data set includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family (pp. 500-525).  Each species is identified as definitely edible, definitely 
# ...

# %%
print(mushroom.metadata['additional_info']['summary'])
# Out:
# This data set includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family (pp. 500-525).  Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended.  This latter class was combined with the poisonous one.  The Guide clearly states that there is no simple rule for determining the edibility of a mushroom; no rule like ``leaflets three, let it be'' for Poisonous Oak and Ivy.

# %%
X = X_original.copy()

# %%
print(X.head())
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape  ... stalk-surface-below-ring  \
# 0         n          k           e  ...                        s
# 1         b          k           e  ...                        s
# 2         b          n           e  ...                        s
# 3         n          n           e  ...                        s
# 4         b          k           t  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
print(X.shape)
# Out:
# (8124, 22)

# %%
print(X.dtypes)
# Out:
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
print(X.columns)
# Out:
# Index(['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
for column in X.columns:
    list = mushroom.variables.description[mushroom.variables.name == column].tolist()
    pieces = list[0].split(',')
    dict = {}
    for piece in pieces:
        value, key = piece.split('=')
        dict[key] = value

    X[column] = X[column].map(dict)
    
print(X.head())
# Out:
#   cap-shape cap-surface cap-color  bruises     odor gill-attachment  \
# 0    convex      smooth     brown  bruises  pungent            free
# 1    convex      smooth    yellow  bruises   almond            free
# 2      bell      smooth     white  bruises    anise            free
# 3    convex       scaly     white  bruises  pungent            free
# 4    convex      smooth      gray       no     none            free
#
#   gill-spacing gill-size gill-color stalk-shape  ... stalk-surface-below-ring  \
# 0        close    narrow      black   enlarging  ...                   smooth
# 1        close     broad      black   enlarging  ...                   smooth
# 2        close     broad      brown   enlarging  ...                   smooth
# 3        close    narrow      brown   enlarging  ...                   smooth
# 4      crowded     broad      black    tapering  ...                   smooth
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
sns.countplot(x = y_original.poisonous, stat = 'proportion', hue = y_original.poisonous)
# Out:
# <Axes: xlabel='poisonous', ylabel='proportion'>

# %%
fig, axs = plt.subplots(5, 5, figsize = (25, 15))
axs = axs.flatten()

for i, col in enumerate(X.columns):
    
    sns.countplot(ax = axs[i], data = X, x = col, order = X[col].value_counts().index, stat = 'proportion', hue = col, palette = 'magma')
    axs[i].set_xlabel(col.replace('-', ' '))
    
for j in range(len(X.columns), len(axs)):
    axs[j].axis('off') 
    
plt.ylabel('Proportion')
plt.tight_layout()
plt.show()
plt.close()

# %% [markdown]
# There is only one type of veil so we can drop this feature.
#
# The veil color is white in almost all cases, not much variability here.
#
# In almost 90% of cases, the ring number is one, also not much variance.
#
# The gill attachment is free in almost all samples.
#
# The gill spacing is close in 80% of cases, still I will keep this feature for now.

# %%
X = X.drop(['veil-type', 'veil-color', 'gill-attachment', 'ring-number'], axis = 1)

# %% [markdown]
# Now that I have an idea of the data, I want to see if there are some correlations with the target variable.

# %%
X = X.fillna(value = {'stalk-root':'unknown'})
print(X.isna().sum()/len(X))
# Out:
# cap-shape                   0.0
# cap-surface                 0.0
# cap-color                   0.0
# bruises                     0.0
# odor                        0.0
# gill-spacing                0.0
# gill-size                   0.0
# gill-color                  0.0
# stalk-shape                 0.0
# stalk-root                  0.0
# stalk-surface-above-ring    0.0
# stalk-surface-below-ring    0.0
# stalk-color-above-ring      0.0
# stalk-color-below-ring      0.0
# ring-type                   0.0
# spore-print-color           0.0
# population                  0.0
# habitat                     0.0
# dtype: float64

# %% [markdown]
# 30% of samples miss a classification for stalk-root. It's too much data to just eliminate the rows. There are three approaches possible:
#
# 1. filling with 'unknown'
# 2. filling with single imputation
# 3. filling with multiple imputation
#
# I will try and go on with the first option then test the other two.

# %%
contingency_table = pd.crosstab(X['bruises'], y_original.poisonous) 
chi2, p, dof, _ = chi2_contingency(contingency_table)
print(chi2, p)
# Out:
# 2041.4156474619554 0.0

# %%
def chi2_test(column):
    contingency_table = pd.crosstab(column, y_original.poisonous) 
    chi2, p, dof, _ = chi2_contingency(contingency_table)
    n = contingency_table.sum().sum()
    k = min(contingency_table.shape) - 1
    cramers_v_value = np.sqrt(chi2 / (n * k))
    return pd.Series({'Chi2': chi2, 'p-value': p, 'Cramer\'s V': cramers_v_value})

results_df = X.apply(chi2_test)
print(results_df)
# Out:
#                 cap-shape   cap-surface     cap-color      bruises  \
# Chi2         4.899200e+02  3.150428e+02  3.875978e+02  2041.415647
# p-value     1.196457e-103  5.518427e-68  6.055815e-78     0.000000
# Cramer's V   2.455713e-01  1.969245e-01  2.184267e-01     0.501280
#
#                    odor   gill-spacing    gill-size   gill-color  \
# Chi2        7659.726740   9.841433e+02  2366.834257  3765.714086
# p-value        0.000000  5.022978e-216     0.000000     0.000000
# Cramer's V     0.971005   3.480521e-01     0.539758     0.680830
#
#              stalk-shape     stalk-root  stalk-surface-above-ring  \
# Chi2        8.414204e+01   1.344441e+03               2808.286287
# p-value     4.604746e-20  7.702048e-290                  0.000000
# Cramer's V  1.017704e-01   4.068046e-01                  0.587944
#
#             stalk-surface-below-ring  stalk-color-above-ring  \
# Chi2                     2684.474076             2237.898496
# ...

# %% [markdown]
# Because of the large sample size, the p-value is biased towards lower values, giving a false impression of association. In this case, I use cramer's v to get an idea of the strength of the association, regardless of the sample size.
#
# Values between 0.3 and 0.5 indicate strong association while values above 0.7 indicate very strong association. <br>
# Based on the cramer's v metric, the features that have the strongest correlation with the target variable are:  odor, spore-print-color, ring-type,gill-size, gill-color, stalk-surface-above-ring, stalk-surface-below-ring, stalk-color-above-ring, stalk-color-below-ring, bruises
#
# The features that have little association with the target variable are: cap-shape, cap-surface, cap-color, gill-spacing, stalk-shape, stalk-root. These are candidates for removal.

# %%
X = X.drop(['cap-shape', 'cap-surface', 'cap-color', 'gill-spacing', 'stalk-shape', 'stalk-root'], axis = 1)

# %%
print(X.columns)
print(X.shape)
# Out:
# Index(['bruises', 'odor', 'gill-size', 'gill-color',
#        'stalk-surface-above-ring', 'stalk-surface-below-ring',
#        'stalk-color-above-ring', 'stalk-color-below-ring', 'ring-type',
#        'spore-print-color', 'population', 'habitat'],
#       dtype='object')
# (8124, 12)

# %% [markdown]
# I want to look at the correlation between the features to check for multicollinearity.

# %%
def chi2_test_feature_pair(feature1, feature2):
    contingency_table = pd.crosstab(feature1, feature2)
    chi2, p, dof, _ = chi2_contingency(contingency_table)
    n = contingency_table.sum().sum()
    k = min(contingency_table.shape) - 1
    cramers_v_value = np.sqrt(chi2 / (n * k))
    return chi2, p, dof, cramers_v_value
    
results = []

for feature1 in X.columns:
    for feature2 in X.columns:  
        chi2, p, dof, cramers_v_value = chi2_test_feature_pair(X[feature1], X[feature2])
        results.append({'Feature1': feature1, 'Feature2': feature2, 'Chi2': chi2, 'P-value': p, 'DOF': dof, 'Cramer\'s V': cramers_v_value})
        results_df2 = pd.DataFrame(results)        

print(results_df2)
# Out:
#     Feature1                  Feature2          Chi2        P-value  DOF  \
# 0    bruises                   bruises   8119.883087   0.000000e+00    1
# 1    bruises                      odor   3548.535179   0.000000e+00    8
# 2    bruises                 gill-size   1108.124760  5.662661e-243    1
# 3    bruises                gill-color   3435.836879   0.000000e+00   11
# 4    bruises  stalk-surface-above-ring   2687.718334   0.000000e+00    3
# ..       ...                       ...           ...            ...  ...
# 139  habitat    stalk-color-below-ring   8510.551329   0.000000e+00   48
# 140  habitat                 ring-type   2998.165127   0.000000e+00   24
# 141  habitat         spore-print-color   5177.935241   0.000000e+00   48
# 142  habitat                population  10431.001581   0.000000e+00   30
# 143  habitat                   habitat  48744.000000   0.000000e+00   36
#
#      Cramer's V
# 0      0.999747
# 1      0.660906
# 2      0.369326
# 3      0.650326
# ...

# %%
correlation_matrix = pd.pivot_table(data = results_df2, index= 'Feature1', columns='Feature2', values = "Cramer's V")

sns.heatmap(data = correlation_matrix)
plt.show()
plt.close()

# %%
print(results_df2[['Feature1', 'Feature2', 'Cramer\'s V']][(results_df2["Cramer's V"]>0.7) & (results_df2["Cramer's V"]<0.999)])

# %% [markdown]
# There are three pairs of features that are highly correlated:
# - bruises and ring-type
# - odor and gill-size
# - gill-size and gill-color
# This means we can keep only three of the six features and still obtain meaningful results. But which ones to eliminate? I think we should look back at the correlation with the target variable.

# %%
print(results_df[['bruises', 'ring-type', 'odor', 'gill-size', 'gill-color']])
# Out:
#                 bruises    ring-type         odor    gill-size   gill-color
# Chi2        2041.415647  2956.619278  7659.726740  2366.834257  3765.714086
# p-value        0.000000     0.000000     0.000000     0.000000     0.000000
# Cramer's V     0.501280     0.603271     0.971005     0.539758     0.680830

# %% [markdown]
# Ring type has a higher correlation to the target compared to bruises <br>
# Odor has a much higher association to the target compared to gill-size<br>
# Gill color has a higher correlation to the target compared to gill-size<br>
#
# Thus bruises and gill-size will be eliminated.

# %%
X = X.drop(['bruises', 'gill-size'], axis = 1)

# %%
print(X.columns)
print(X.shape)
# Out:
# Index(['odor', 'gill-color', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'ring-type', 'spore-print-color',
#        'population', 'habitat'],
#       dtype='object')
# (8124, 10)

# %% [markdown]
# We started with 22 and have now only 10 features. I think we can proceed with a wrapper method. <br>
# The data calls for a classification algorithm and since we have labels we can choose among: KNN, Decision Trees and SVCs.<br>
# I will try all of them and see which one works best. Now for the wrapper method there are various options but I will start with doing a random forest first to see a ranking of the feature importances.

# %%
for column in X.columns:
    print(f'{column}: {X[column].nunique()}')
# Out:
# odor: 9
# gill-color: 12
# stalk-surface-above-ring: 4
# stalk-surface-below-ring: 4
# stalk-color-above-ring: 9
# stalk-color-below-ring: 9
# ring-type: 5
# spore-print-color: 9
# population: 6
# habitat: 7

# %%
y = y_original.poisonous.map({'e':1, 'p':0})

# %%
encoder = ce.BinaryEncoder()
encoded_data = encoder.fit_transform(X)
print(encoded_data.shape)
# Out:
# (8124, 35)

# %%
x_train, x_test, y_train, y_test = train_test_split(encoded_data, y, test_size= 0.2, random_state=99)

rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)

y_pred = rfc.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
print(confusion_matrix)
print(f'Accuracy: {accuracy}\nConfusionMatrix: {cm}\nF1 score: {f1}\nPrecision:{precision}')
# Out:
# <function confusion_matrix at 0x00000219958EF420>
# Accuracy: 1.0
# ConfusionMatrix: [[812   0]
#  [  0 813]]
# F1 score: 1.0
# Precision:1.0

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)  

scores = cross_val_score(rfc, encoded_data, y, cv=kf, scoring='f1') 
print(scores)
# Out:
# [1. 1. 1. 1. 1.]

# %%
feature_importance_df = pd.DataFrame({
    'Feature': encoded_data.columns,
    'Importance': rfc.feature_importances_
}).sort_values(by='Importance', ascending=False)

print(feature_importance_df)
# Out:
#                        Feature  Importance
# 3                       odor_3    0.141748
# 26         spore-print-color_1    0.128721
# 23                 ring-type_1    0.084137
# 2                       odor_2    0.067967
# 11  stalk-surface-below-ring_0    0.066950
# 9   stalk-surface-above-ring_1    0.049543
# 29                population_0    0.049392
# 4                 gill-color_0    0.044564
# 30                population_1    0.038421
# 1                       odor_1    0.032972
# 33                   habitat_1    0.028969
# 13  stalk-surface-below-ring_2    0.025109
# 32                   habitat_0    0.022763
# 0                       odor_0    0.022291
# 27         spore-print-color_2    0.020331
# 31                population_2    0.020212
# 34                   habitat_2    0.018906
# 28         spore-print-color_3    0.018659
# 24                 ring-type_2    0.014574
# 5                 gill-color_1    0.011751
# 19    stalk-color-below-ring_1    0.010792
# ...

# %%
df = feature_importance_df.set_index('Feature')
print(df)
# Out:
#                             Importance
# Feature
# odor_3                        0.141748
# spore-print-color_1           0.128721
# ring-type_1                   0.084137
# odor_2                        0.067967
# stalk-surface-below-ring_0    0.066950
# stalk-surface-above-ring_1    0.049543
# population_0                  0.049392
# gill-color_0                  0.044564
# population_1                  0.038421
# odor_1                        0.032972
# habitat_1                     0.028969
# stalk-surface-below-ring_2    0.025109
# habitat_0                     0.022763
# odor_0                        0.022291
# spore-print-color_2           0.020331
# population_2                  0.020212
# habitat_2                     0.018906
# spore-print-color_3           0.018659
# ring-type_2                   0.014574
# gill-color_1                  0.011751
# stalk-color-below-ring_1      0.010792
# gill-color_3                  0.010026
# stalk-color-above-ring_2      0.009954
# ...

# %%
aggregated_importance = {}

print(df.filter(like='odor', axis = 0))
    
for category in X.columns:
    cols = df.Importance.filter(like=category).tolist()
    if cols:
        aggregated_importance[category] = df[df.isin(cols)]['Importance'].sum()
print(aggregated_importance)
# Out:
#          Importance
# Feature
# odor_3     0.141748
# odor_2     0.067967
# odor_1     0.032972
# odor_0     0.022291
# {'odor': 0.2649777466556142, 'gill-color': 0.07163091090207992, 'stalk-surface-above-ring': 0.06036486887937052, 'stalk-surface-below-ring': 0.10107032779092162, 'stalk-color-above-ring': 0.022022138813418808, 'stalk-color-below-ring': 0.032262275854264874, 'ring-type': 0.10094761268768657, 'spore-print-color': 0.16806189636681276, 'population': 0.10802455388054671, 'habitat': 0.07063766816928399}

# %%
aggregated_importance = {}
    
for category in X.columns:
    cols = df.Importance.filter(like=category).tolist()
    if cols:
        aggregated_importance[category] = df[df.isin(cols)]['Importance'].sum()
    original_imp = pd.DataFrame(aggregated_importance.values(), index = aggregated_importance.keys(), columns=['Aggregated importance'])
    original_imp = original_imp.sort_values(by = 'Aggregated importance', ascending = False)

print(original_imp)
# Out:
#                           Aggregated importance
# odor                                   0.264978
# spore-print-color                      0.168062
# population                             0.108025
# stalk-surface-below-ring               0.101070
# ring-type                              0.100948
# gill-color                             0.071631
# habitat                                0.070638
# stalk-surface-above-ring               0.060365
# stalk-color-below-ring                 0.032262
# stalk-color-above-ring                 0.022022

# %% [markdown]
# Based on the Random Forest Classifier, the most important features (0.92) are odor, spore-print-color, population, surface below ring, ring type, gill color, habitat and surface above ring.

# %%
disp = PartialDependenceDisplay.from_estimator(rfc, encoded_data, y, kind = 'average')
plt.show()
